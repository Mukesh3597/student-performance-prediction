# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\mukes\Downloads\Final_Marks_Data.csv")

# %%
df.head()
# Out:
#   Student_ID  Attendance (%)  Internal Test 1 (out of 40)  \
# 0      S1000              84                           30
# 1      S1001              91                           24
# 2      S1002              73                           29
# 3      S1003              80                           36
# 4      S1004              84                           31
#
#    Internal Test 2 (out of 40)  Assignment Score (out of 10)  \
# 0                           36                             7
# 1                           38                             6
# 2                           26                             7
# 3                           35                             7
# 4                           37                             8
#
#    Daily Study Hours  Final Exam Marks (out of 100)
# 0                  3                             72
# 1                  3                             56
# 2                  3                             56
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                       0
# Attendance (%)                   0
# Internal Test 1 (out of 40)      0
# Internal Test 2 (out of 40)      0
# Assignment Score (out of 10)     0
# Daily Study Hours                0
# Final Exam Marks (out of 100)    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Student_ID                     2000 non-null   object
#  1   Attendance (%)                 2000 non-null   int64
#  2   Internal Test 1 (out of 40)    2000 non-null   int64
#  3   Internal Test 2 (out of 40)    2000 non-null   int64
#  4   Assignment Score (out of 10)   2000 non-null   int64
#  5   Daily Study Hours              2000 non-null   int64
#  6   Final Exam Marks (out of 100)  2000 non-null   int64
# dtypes: int64(6), object(1)
# memory usage: 109.5+ KB

# %%
lr = LabelEncoder()

# %%
df["Student_ID"] = lr.fit_transform(df["Student_ID"])

# %%
df
# Out:
#       Student_ID  Attendance (%)  Internal Test 1 (out of 40)  \
# 0              0              84                           30
# 1              1              91                           24
# 2              2              73                           29
# 3              3              80                           36
# 4              4              84                           31
# ...          ...             ...                          ...
# 1995        1995              82                           31
# 1996        1996              78                           38
# 1997        1997              78                           30
# 1998        1998              82                           29
# 1999        1999              97                           32
#
#       Internal Test 2 (out of 40)  Assignment Score (out of 10)  \
# 0                              36                             7
# 1                              38                             6
# ...

# %%
x = df.iloc[:,:-1]
y = df[["Final Exam Marks (out of 100)"]]

# %%
sc =StandardScaler()

# %%
sclar =pd.DataFrame(sc.fit_transform(x),columns=x.columns)

# %%
sclar
# Out:
#       Student_ID  Attendance (%)  Internal Test 1 (out of 40)  \
# 0      -1.731185       -0.114930                    -0.463685
# 1      -1.729453        0.787491                    -1.778793
# 2      -1.727721       -1.533019                    -0.682870
# 3      -1.725989       -0.630599                     0.851423
# 4      -1.724257       -0.114930                    -0.244500
# ...          ...             ...                          ...
# 1995    1.724257       -0.372764                    -0.244500
# 1996    1.725989       -0.888433                     1.289792
# 1997    1.727721       -0.888433                    -0.463685
# 1998    1.729453       -0.372764                    -0.682870
# 1999    1.731185        1.560994                    -0.025316
#
#       Internal Test 2 (out of 40)  Assignment Score (out of 10)  \
# 0                        0.781897                     -0.496689
# 1                        1.224209                     -1.476351
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)*100,model.score(x_test,y_test)*100
# Out:
# (83.9007269962731, 82.91237606038955)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Predictions
y_pred = model.predict(x_test)

# R2 Score (accuracy like)
r2 = r2_score(y_test, y_pred)

# Errors
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print("R2 Score:", r2)
print("MAE:", mae)
print("MSE:", mse)
# Out:
# R2 Score: 0.8291237606038955
# MAE: 3.6928684491696675
# MSE: 21.400608572463884

# %%
encoded_id = lr.transform(["S1000"])[0]   # Student_ID encode

data = [[
    encoded_id,   # Student_ID
    84,           # Attendance (%)
    36,           # Internal Test 1
    30,           # Internal Test 2
    7,            # Assignment Score
    3             # Daily Study Hours
]]

scaled = sc.transform(data)
prediction = model.predict(scaled)

print("Predicted Marks:", prediction[0][0])
# Out:
# Running cells with 'Python 3.12.6' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/mukes/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'
